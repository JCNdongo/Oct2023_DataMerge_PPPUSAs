# %% [markdown]
# ## <center/> Retrieving data from 2023 USASpending.gov data for file 1 of 6 <center> ##

# %% [markdown]
# #### Retrieving csv file and reading it into a Pandas DataFrame ####

# %%
#dependencies
import pandas as pd
import os

# %%
# Define the file paths
source_folder = r"F:\FAU PhD\DISSERTATION\DATABASES\06.30.2023 Data Search\2023 FULL Award Data Archive"
output_folder = r"F:\FAU PhD\DISSERTATION\DATABASES\DataTESTS\Oct.23.2023.Test\2022_2023"
file_name = "FY2023_All_Contracts_Full_20231008_1.csv"

# %%
# Read the CSV file into a dataframe
df = pd.read_csv(f"{source_folder}\\{file_name}")
df.head()
# Out:
# C:\Users\mjndo\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (47,71,81,107,108,115,116,135,136,164,165,179,180) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                    contract_transaction_unique_key  \
# 0      3600_4730_36C24221F0035_P00006_GS07F9298S_0
# 1  1560_4730_15A00021FAQA00007_P00005_GS35F0074W_0
# 2        4732_4732_47QSCC23F81TF_0_47QSCC20D0010_0
# 3           4732_4730_47QSEA23F9JVQ_0_GS02FW0003_0
# 4        4732_4732_47QSEA23F9JS1_0_47QSEA20A000C_0
#
#                          contract_award_unique_key      award_id_piid  \
# 0      CONT_AWD_36C24221F0035_3600_GS07F9298S_4730      36C24221F0035
# 1  CONT_AWD_15A00021FAQA00007_1560_GS35F0074W_4730  15A00021FAQA00007
# 2   CONT_AWD_47QSCC23F81TF_4732_47QSCC20D0010_4732      47QSCC23F81TF
# 3      CONT_AWD_47QSEA23F9JVQ_4732_GS02FW0003_4730      47QSEA23F9JVQ
# 4   CONT_AWD_47QSEA23F9JS1_4732_47QSEA20A000C_4732      47QSEA23F9JS1
#
#   modification_number  transaction_number parent_award_agency_id  \
# 0              P00006                 0.0                   4730
# 1              P00005                 0.0                   4730
# 2                   0                 0.0                   4732
# 3                   0                 0.0                   4730
# 4                   0                 0.0                   4732
#
#       parent_award_agency_name parent_award_id_piid  \
# 0  FEDERAL ACQUISITION SERVICE           GS07F9298S
# 1  FEDERAL ACQUISITION SERVICE           GS35F0074W
# 2  FEDERAL ACQUISITION SERVICE        47QSCC20D0010
# 3  FEDERAL ACQUISITION SERVICE           GS02FW0003
# 4  FEDERAL ACQUISITION SERVICE        47QSEA20A000C
#
#   parent_award_modification_number  federal_action_obligation  ...  \
# 0                           AO0084                       0.00  ...
# 1                 PA0036ADDRESSCHG                       0.00  ...
# 2                           PS0001                      47.43  ...
# 3                           PW0077                      24.18  ...
# 4                           PO0004                     119.80  ...
#
#    highly_compensated_officer_2_name  highly_compensated_officer_2_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                      THOMAS  HOUSE                             442067.0
#
#    highly_compensated_officer_3_name  highly_compensated_officer_3_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                   NEIL  SIDEBOTHAM                             388937.0
#
#    highly_compensated_officer_4_name  highly_compensated_officer_4_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                 VINCENT L GRIFFITH                             361346.0
#
#   highly_compensated_officer_5_name  highly_compensated_officer_5_amount  \
# 0                               NaN                                  NaN
# 1                               NaN                                  NaN
# 2                               NaN                                  NaN
# 3                               NaN                                  NaN
# 4                   ROBERT  LEDENKO                             360871.0
#
#                                usaspending_permalink  last_modified_date
# 0  https://www.usaspending.gov/award/CONT_AWD_36C...          2023-09-30
# 1  https://www.usaspending.gov/award/CONT_AWD_15A...          2023-09-30
# 2  https://www.usaspending.gov/award/CONT_AWD_47Q...          2023-10-01
# 3  https://www.usaspending.gov/award/CONT_AWD_47Q...          2023-10-01
# 4  https://www.usaspending.gov/award/CONT_AWD_47Q...          2023-10-01
#
# [5 rows x 296 columns]

# %% [markdown]
# #### Filtering the data by to capture ONLY businesses that were designated as "Small Businesses" by contracting officers, headquartered in the US and providing goods and services to US federal government agencies. ####

# %%
# Filter the dataframe
df_filtered = df[
    (df['contracting_officers_determination_of_business_size'] == 'SMALL BUSINESS') &
    (df['recipient_country_code'] == 'USA') &
    (df['primary_place_of_performance_country_code'] == 'USA')
]

# %% [markdown]
# #### The data includes several rows for each business; therefore, I am aggregating the data to only have 1 row per business then retaining only the data points that I need for the analysis ####

# %%
# Aggregate the filtered dataframe
aggregation_functions = {
    'total_dollars_obligated': 'sum',
    'total_outlayed_amount_for_overall_award': 'sum',
    'current_total_value_of_award': 'sum',
    'base_and_all_options_value': 'sum',
    'potential_total_value_of_award': 'sum',
    'number_of_offers_received': 'sum',
    'recipient_name': 'first',
    'recipient_doing_business_as_name': 'first',
    'recipient_uei': 'first',
    'recipient_duns': 'first',
    'recipient_phone_number': 'first',
    'recipient_city_name': 'first',
    'recipient_state_code': 'first',
    'recipient_zip_4_code': 'first',
    'naics_code': 'first',
    'naics_description': 'first',
    'alaskan_native_corporation_owned_firm': 'first',
    'american_indian_owned_business': 'first',
    'indian_tribe_federally_recognized': 'first',
    'native_hawaiian_organization_owned_firm': 'first',
    'tribally_owned_firm': 'first',
    'veteran_owned_business': 'first',
    'service_disabled_veteran_owned_business': 'first',
    'woman_owned_business': 'first',
    'women_owned_small_business': 'first',
    'economically_disadvantaged_women_owned_small_business': 'first',
    'joint_venture_women_owned_small_business': 'first',
    'joint_venture_economic_disadvantaged_women_owned_small_bus': 'first',
    'minority_owned_business': 'first',
    'subcontinent_asian_asian_indian_american_owned_business': 'first',
    'asian_pacific_american_owned_business': 'first',
    'black_american_owned_business': 'first',
    'hispanic_american_owned_business': 'first',
    'native_american_owned_business': 'first',
    'other_minority_owned_business': 'first',
    'historically_underutilized_business_zone_hubzone_firm': 'first'
}

# %%
df_aggregated = df_filtered.groupby('recipient_uei').agg(aggregation_functions)

# %%
df_aggregated.shape
# Out:
# (36178, 36)

# %%
# Rename columns
df_aggregated.rename(columns={
    'total_dollars_obligated': '2023_total_dollars_obligated',
    'total_outlayed_amount_for_overall_award': '2023_total_outlayed_amount_for_overall_award',
    'current_total_value_of_award': '2023_current_total_value_of_award',
    'base_and_all_options_value': '2023_base_and_all_options_value',
    'potential_total_value_of_award': '2023_potential_total_value_of_award',
    'number_of_offers_received': '2023_number_of_offers_received',
    'recipient_uei': 'Businessuei',
    'recipient_duns': 'businessduns',
    'recipient_name': 'Businessname',
    'recipient_doing_business_as_name': 'businessdba',
    'recipient_phone_number': 'Phone',
    'recipient_city_name': 'City',
    'recipient_state_code': 'State',
    'recipient_zip_4_code': 'ZipCode',
    'naics_code': 'NAICS',
    'naics_description': 'NAICSDescription',
    'alaskan_native_corporation_owned_firm': 'alaskan_native',
    'american_indian_owned_business': 'american_indian',
    'indian_tribe_federally_recognized': 'indian_tribe',
    'native_hawaiian_organization_owned_firm': 'native_hawaiian',
    'tribally_owned_firm': 'tribally_owned',
    'veteran_owned_business': 'veteran_owned',
    'service_disabled_veteran_owned_business': 'service_disabled_veteran',
    'woman_owned_business': 'woman_owned',
    'women_owned_small_business': 'WOSB',
    'economically_disadvantaged_women_owned_small_business': 'econ_disadv_WOSB',
    'joint_venture_women_owned_small_business': 'jointVenture_WOSB',
    'joint_venture_economic_disadvantaged_women_owned_small_bus': 'jointVenture_econ_disadv_WOSB',
    'minority_owned_business': 'minority_owned',
    'subcontinent_asian_asian_indian_american_owned_business': 'subcontinent_asian_indian_american',
    'asian_pacific_american_owned_business': 'asian_pacific_american',
    'black_american_owned_business': 'black_american',
    'hispanic_american_owned_business': 'hispanic_american',
    'native_american_owned_business': 'native_american',
    'other_minority_owned_business': 'other_minority',
    'historically_underutilized_business_zone_hubzone_firm': 'hubzone'
}, inplace=True)

# %%
df_aggregated.head()
# Out:
#                2023_total_dollars_obligated  \
# recipient_uei
# C116E6T5MGD6                     1702950.88
# C117W2NX6Y85                       55214.80
# C11LLU3R9JF8                       65595.60
# C11UNZ93M595                       79867.36
# C126Y284ZBC6                     3130836.72
#
#                2023_total_outlayed_amount_for_overall_award  \
# recipient_uei
# C116E6T5MGD6                                           0.00
# C117W2NX6Y85                                           0.00
# C11LLU3R9JF8                                           0.00
# C11UNZ93M595                                       79867.36
# C126Y284ZBC6                                      589272.32
#
#                2023_current_total_value_of_award  \
# recipient_uei
# C116E6T5MGD6                          8314573.52
# C117W2NX6Y85                           138037.00
# C11LLU3R9JF8                            65595.60
# C11UNZ93M595                            79867.36
# C126Y284ZBC6                          3289083.12
#
#                2023_base_and_all_options_value  \
# recipient_uei
# C116E6T5MGD6                              0.00
# C117W2NX6Y85                         244466.60
# C11LLU3R9JF8                          65595.60
# C11UNZ93M595                              0.00
# C126Y284ZBC6                         167535.34
#
#                2023_potential_total_value_of_award  \
# recipient_uei
# C116E6T5MGD6                            8599439.76
# C117W2NX6Y85                             244466.60
# C11LLU3R9JF8                              65595.60
# C11UNZ93M595                             404796.90
# C126Y284ZBC6                            5083963.40
#
#                2023_number_of_offers_received  \
# recipient_uei
# C116E6T5MGD6                              1.0
# C117W2NX6Y85                              0.0
# C11LLU3R9JF8                              2.0
# C11UNZ93M595                              4.0
# C126Y284ZBC6                              5.0
#
#                                              Businessname businessdba  \
# recipient_uei
# C116E6T5MGD6                             MARZEN GROUP LLC        None
# C117W2NX6Y85                       THERAPATH PARTNERS LLC        None
# C11LLU3R9JF8                                 HOLLY LEAH P        None
# C11UNZ93M595   ENTERPRISE SERVICES AND TECHNOLOGIES, INC.        None
# C126Y284ZBC6                              JAM SYSTEMS LLC        None
#
#                 Businessuei  businessduns  ... jointVenture_WOSB  \
# recipient_uei                              ...
# C116E6T5MGD6   C116E6T5MGD6           NaN  ...                 f
# C117W2NX6Y85   C117W2NX6Y85           NaN  ...                 f
# C11LLU3R9JF8   C11LLU3R9JF8           NaN  ...                 f
# C11UNZ93M595   C11UNZ93M595           NaN  ...                 f
# C126Y284ZBC6   C126Y284ZBC6           NaN  ...                 f
#
#               jointVenture_econ_disadv_WOSB minority_owned  \
# recipient_uei
# C116E6T5MGD6                              f              f
# C117W2NX6Y85                              f              f
# C11LLU3R9JF8                              f              f
# C11UNZ93M595                              f              t
# C126Y284ZBC6                              f              t
#
#               subcontinent_asian_indian_american  asian_pacific_american  \
# recipient_uei
# C116E6T5MGD6                                   f                       f
# C117W2NX6Y85                                   f                       f
# C11LLU3R9JF8                                   f                       f
# C11UNZ93M595                                   f                       f
# C126Y284ZBC6                                   f                       f
#
#               black_american hispanic_american native_american other_minority  \
# recipient_uei
# C116E6T5MGD6               f                 f               f              f
# C117W2NX6Y85               f                 f               f              f
# C11LLU3R9JF8               f                 f               f              f
# C11UNZ93M595               t                 f               f              f
# C126Y284ZBC6               t                 f               f              f
#
#               hubzone
# recipient_uei
# C116E6T5MGD6        f
# C117W2NX6Y85        f
# C11LLU3R9JF8        f
# C11UNZ93M595        f
# C126Y284ZBC6        f
#
# [5 rows x 36 columns]

# %%
# Save the final dataframe to a CSV file in the output folder
output_file_name = "2023_Contracting_1.csv"
df_aggregated.to_csv(f"{output_folder}\\{output_file_name}", index=False)

print(f"Aggregated file saved at {output_folder}")
# Out:
# Aggregated file saved at F:\FAU PhD\DISSERTATION\DATABASES\DataTESTS\Oct.23.2023.Test\2022_2023
